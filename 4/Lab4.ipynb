# %% [markdown]
# ## Задание №1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tzi — момент прихода заявки
# Tsi-1 — момент окончания предыдущего обслуживания
# dtw — допустимое время ожидания

# %%
def simulate_system(lambda_, mu, Tw_max, T):
    t = 0  # текущее время
    Ts_prev = 0  # момент окончания предыдущего обслуживания
    
    served = 0
    rejected = 0
    total_wait_time = 0
    idle_time = 0
    busy_time = 0
    
    arrival_times = []
    
    # Генерация потока заявок
    while t < T:
        dt = np.random.exponential(1 / lambda_)
        t += dt
        if t > T:
            break
        arrival_times.append(t)
    
    for Tzi in arrival_times:
        
        # допустимое время ожидания (равномерное распределение)
        dtw = np.random.uniform(0, Tw_max)
        deadline = Tzi + dtw
        
        # Вариант отказа
        if deadline < Ts_prev:
            rejected += 1
            continue
        
        # Вариант 2 — сервер свободен
        if Tzi >= Ts_prev:
            idle_time += Tzi - Ts_prev
            start_service = Tzi
        else:
            # Вариант 3 — ожидание
            wait = Ts_prev - Tzi
            total_wait_time += wait
            start_service = Ts_prev
        
        service_time = np.random.exponential(1 / mu)
        Ts_prev = start_service + service_time
        
        busy_time += service_time
        served += 1
    
    total_requests = served + rejected
    
    results = {
        "served": served,
        "rejected": rejected,
        "p_served": served / total_requests if total_requests else 0,
        "p_rejected": rejected / total_requests if total_requests else 0,
        "idle_time": idle_time,
        "total_wait_time": total_wait_time,
        "avg_wait_time": total_wait_time / served if served else 0,
        "utilization": busy_time / T
    }
    
    return results

# %% [markdown]
# ## Задание №2

# %%
lambda_ = 0.7 # интенсивность входного потока
mu = 0.8 # интенсивность обработки заявок
Tw_max = 1.0 # максимальное допустимое время ожидания
T = 1000 # суммарное время моделирования

result = simulate_system(lambda_, mu, Tw_max, T)

for key, value in result.items():
    print(f"{key}: {value:.4f}")
# Out:
# served: 458.0000
# rejected: 300.0000
# p_served: 0.6042
# p_rejected: 0.3958
# idle_time: 442.7664
# total_wait_time: 37.3080
# avg_wait_time: 0.0815
# utilization: 0.5572

# %% [markdown]
# ## Задание №3

# %%
Tw_values = np.linspace(0, 10, 50)

p_served_list = []
p_rejected_list = []
utilization_list = []
total_wait_list = []
avg_wait_list = []

for Tw in Tw_values:
    res = simulate_system(lambda_=0.7, mu=0.8, Tw_max=Tw, T=1000)
    
    p_served_list.append(res["p_served"])
    p_rejected_list.append(res["p_rejected"])
    utilization_list.append(res["utilization"])
    total_wait_list.append(res["total_wait_time"])
    avg_wait_list.append(res["avg_wait_time"])

# %%
plt.figure()
plt.plot(Tw_values, p_served_list)
plt.plot(Tw_values, p_rejected_list)
plt.xlabel("Tw_max")
plt.ylabel("Probability")
plt.title("Вероятность обслуживания и отказа")
plt.show()

# %%
plt.figure()
plt.plot(Tw_values, utilization_list)
plt.xlabel("Tw_max")
plt.ylabel("Utilization")
plt.title("Вероятность загрузки сервера")
plt.show()

# %%
plt.figure()
plt.plot(Tw_values, total_wait_list)
plt.xlabel("Tw_max")
plt.ylabel("Total wait time")
plt.title("Суммарное время ожидания")
plt.show()

# %%
plt.figure()
plt.plot(Tw_values, avg_wait_list)
plt.xlabel("Tw_max")
plt.ylabel("Average wait time")
plt.title("Среднее время ожидания")
plt.show()

# %% [markdown]
# ## Задание №4

# %%
optimal_Tw = None

for Tw in np.linspace(0, 10, 100):
    res = simulate_system(lambda_=0.7, mu=0.8, Tw_max=Tw, T=2000)
    
    print(f"Tw={Tw:.2f}, "
          f"P_served={res['p_served']:.3f}, "
          f"Util={res['utilization']:.3f}, "
          f"AvgWait={res['avg_wait_time']:.3f}")
    
    if (res["p_served"] >= 0.8 and
        res["utilization"] >= 0.6 and
        res["avg_wait_time"] <= 0.35):
        
        optimal_Tw = Tw
        break

print(optimal_Tw)
# Out:
# Tw=0.00, P_served=0.551, Util=0.469, AvgWait=0.000
# Tw=0.10, P_served=0.529, Util=0.479, AvgWait=0.001
# Tw=0.20, P_served=0.568, Util=0.493, AvgWait=0.006
# Tw=0.30, P_served=0.557, Util=0.504, AvgWait=0.009
# Tw=0.40, P_served=0.561, Util=0.519, AvgWait=0.018
# Tw=0.51, P_served=0.598, Util=0.516, AvgWait=0.027
# Tw=0.61, P_served=0.569, Util=0.527, AvgWait=0.032
# Tw=0.71, P_served=0.602, Util=0.517, AvgWait=0.040
# Tw=0.81, P_served=0.614, Util=0.531, AvgWait=0.064
# Tw=0.91, P_served=0.621, Util=0.521, AvgWait=0.060
# Tw=1.01, P_served=0.605, Util=0.545, AvgWait=0.094
# Tw=1.11, P_served=0.616, Util=0.547, AvgWait=0.077
# Tw=1.21, P_served=0.624, Util=0.568, AvgWait=0.093
# Tw=1.31, P_served=0.619, Util=0.536, AvgWait=0.119
# Tw=1.41, P_served=0.639, Util=0.551, AvgWait=0.123
# Tw=1.52, P_served=0.646, Util=0.541, AvgWait=0.143
# Tw=1.62, P_served=0.649, Util=0.570, AvgWait=0.154
# Tw=1.72, P_served=0.646, Util=0.558, AvgWait=0.191
# Tw=1.82, P_served=0.665, Util=0.580, AvgWait=0.194
# Tw=1.92, P_served=0.671, Util=0.589, AvgWait=0.217
# Tw=2.02, P_served=0.682, Util=0.583, AvgWait=0.241
# Tw=2.12, P_served=0.670, Util=0.591, AvgWait=0.229
# Tw=2.22, P_served=0.693, Util=0.570, AvgWait=0.232
# Tw=2.32, P_served=0.680, Util=0.588, AvgWait=0.248
# Tw=2.42, P_served=0.663, Util=0.599, AvgWait=0.294
# Tw=2.53, P_served=0.704, Util=0.573, AvgWait=0.301
# Tw=2.63, P_served=0.669, Util=0.601, AvgWait=0.320
# Tw=2.73, P_served=0.699, Util=0.644, AvgWait=0.359
# Tw=2.83, P_served=0.701, Util=0.583, AvgWait=0.313
# Tw=2.93, P_served=0.733, Util=0.570, AvgWait=0.324
# Tw=3.03, P_served=0.700, Util=0.603, AvgWait=0.376
# Tw=3.13, P_served=0.701, Util=0.591, AvgWait=0.383
# Tw=3.23, P_served=0.705, Util=0.621, AvgWait=0.410
# Tw=3.33, P_served=0.699, Util=0.635, AvgWait=0.448
# Tw=3.43, P_served=0.720, Util=0.643, AvgWait=0.449
# Tw=3.54, P_served=0.716, Util=0.637, AvgWait=0.476
# Tw=3.64, P_served=0.737, Util=0.620, AvgWait=0.492
# Tw=3.74, P_served=0.735, Util=0.657, AvgWait=0.563
# Tw=3.84, P_served=0.726, Util=0.638, AvgWait=0.545
# Tw=3.94, P_served=0.746, Util=0.637, AvgWait=0.534
# Tw=4.04, P_served=0.732, Util=0.668, AvgWait=0.561
# Tw=4.14, P_served=0.748, Util=0.639, AvgWait=0.519
# Tw=4.24, P_served=0.768, Util=0.612, AvgWait=0.516
# Tw=4.34, P_served=0.743, Util=0.641, AvgWait=0.557
# Tw=4.44, P_served=0.750, Util=0.624, AvgWait=0.563
# Tw=4.55, P_served=0.777, Util=0.640, AvgWait=0.565
# Tw=4.65, P_served=0.751, Util=0.612, AvgWait=0.582
# Tw=4.75, P_served=0.754, Util=0.673, AvgWait=0.655
# Tw=4.85, P_served=0.771, Util=0.653, AvgWait=0.610
# Tw=4.95, P_served=0.762, Util=0.677, AvgWait=0.677
# Tw=5.05, P_served=0.753, Util=0.646, AvgWait=0.664
# Tw=5.15, P_served=0.756, Util=0.662, AvgWait=0.723
# Tw=5.25, P_served=0.778, Util=0.636, AvgWait=0.628
# Tw=5.35, P_served=0.734, Util=0.685, AvgWait=0.790
# Tw=5.45, P_served=0.749, Util=0.695, AvgWait=0.812
# Tw=5.56, P_served=0.768, Util=0.685, AvgWait=0.817
# Tw=5.66, P_served=0.758, Util=0.664, AvgWait=0.758
# Tw=5.76, P_served=0.754, Util=0.657, AvgWait=0.745
# Tw=5.86, P_served=0.775, Util=0.672, AvgWait=0.888
# Tw=5.96, P_served=0.778, Util=0.676, AvgWait=0.817
# Tw=6.06, P_served=0.760, Util=0.696, AvgWait=0.855
# Tw=6.16, P_served=0.784, Util=0.679, AvgWait=0.799
# Tw=6.26, P_served=0.771, Util=0.676, AvgWait=0.839
# Tw=6.36, P_served=0.781, Util=0.695, AvgWait=0.918
# Tw=6.46, P_served=0.783, Util=0.656, AvgWait=0.786
# Tw=6.57, P_served=0.762, Util=0.682, AvgWait=0.907
# Tw=6.67, P_served=0.770, Util=0.680, AvgWait=0.928
# Tw=6.77, P_served=0.785, Util=0.712, AvgWait=1.004
# Tw=6.87, P_served=0.778, Util=0.656, AvgWait=0.864
# Tw=6.97, P_served=0.791, Util=0.690, AvgWait=0.933
# Tw=7.07, P_served=0.787, Util=0.685, AvgWait=0.958
# Tw=7.17, P_served=0.789, Util=0.722, AvgWait=1.057
# Tw=7.27, P_served=0.794, Util=0.688, AvgWait=0.873
# Tw=7.37, P_served=0.777, Util=0.706, AvgWait=1.060
# Tw=7.47, P_served=0.806, Util=0.682, AvgWait=0.911
# Tw=7.58, P_served=0.798, Util=0.680, AvgWait=0.949
# Tw=7.68, P_served=0.772, Util=0.714, AvgWait=1.120
# Tw=7.78, P_served=0.813, Util=0.671, AvgWait=0.921
# Tw=7.88, P_served=0.764, Util=0.734, AvgWait=1.135
# Tw=7.98, P_served=0.811, Util=0.708, AvgWait=1.111
# Tw=8.08, P_served=0.791, Util=0.681, AvgWait=1.072
# Tw=8.18, P_served=0.787, Util=0.742, AvgWait=1.163
# Tw=8.28, P_served=0.796, Util=0.722, AvgWait=1.137
# Tw=8.38, P_served=0.801, Util=0.709, AvgWait=1.143
# Tw=8.48, P_served=0.807, Util=0.717, AvgWait=1.218
# Tw=8.59, P_served=0.807, Util=0.680, AvgWait=1.038
# Tw=8.69, P_served=0.796, Util=0.700, AvgWait=1.193
# Tw=8.79, P_served=0.793, Util=0.730, AvgWait=1.288
# Tw=8.89, P_served=0.785, Util=0.683, AvgWait=1.226
# Tw=8.99, P_served=0.802, Util=0.718, AvgWait=1.233
# Tw=9.09, P_served=0.795, Util=0.728, AvgWait=1.352
# Tw=9.19, P_served=0.785, Util=0.731, AvgWait=1.309
# Tw=9.29, P_served=0.808, Util=0.679, AvgWait=1.139
# Tw=9.39, P_served=0.792, Util=0.722, AvgWait=1.328
# Tw=9.49, P_served=0.821, Util=0.727, AvgWait=1.213
# Tw=9.60, P_served=0.824, Util=0.687, AvgWait=1.105
# Tw=9.70, P_served=0.808, Util=0.694, AvgWait=1.386
# Tw=9.80, P_served=0.842, Util=0.706, AvgWait=1.273
# Tw=9.90, P_served=0.828, Util=0.717, AvgWait=1.094
# Tw=10.00, P_served=0.802, Util=0.732, AvgWait=1.353
# None
